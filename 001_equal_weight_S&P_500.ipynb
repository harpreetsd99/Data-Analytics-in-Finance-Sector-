# %% [markdown]
# # Equal-Weight S&P 500 Index Fund
#
# ## Introduction & Library Imports
#
# ## Library Imports

# %%
import numpy as np #The Numpy numerical computing library
import pandas as pd #The Pandas data science library
import requests #The requests library for HTTP requests in Python
import xlsxwriter #The XlsxWriter libarary for 
import math #The Python math module

# %% [markdown]
# ## Importing Our List of Stocks

# %%
stocks = pd.read_csv('sp_500_stocks.csv')
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %% [markdown]
# ## Acquiring an API Token

# %%
from api_key_ import IEX_CLOUD_API_TOKEN

# %% [markdown]
# ## Making Our First API Call
#
# We need the following information from the API:
#
# * Market capitalization for each stock
# * Price of each stock

# %%
symbol = 'AAPL'
api_url = f'https://hsdalgotrading.iex.cloud/v1/data/core/quote/{symbol}?token={IEX_CLOUD_API_TOKEN}'
print(api_url)
data = requests.get(api_url).json()
print(data)
# Out:
# https://hsdalgotrading.iex.cloud/v1/data/core/quote/AAPL?token=sk_14ad2778c64a4064b6d4f23dc9f54567
# [{'avgTotalVolume': 66866726, 'calculationPrice': 'close', 'change': 0.86, 'changePercent': 0.00494, 'close': 174.79, 'closeSource': 'official', 'closeTime': 1695412800412, 'companyName': 'Apple Inc', 'currency': 'USD', 'delayedPrice': 174.85, 'delayedPriceTime': 1695412773227, 'extendedChange': 0.15, 'extendedChangePercent': 0.00086, 'extendedPrice': 174.94, 'extendedPriceTime': 1695427193007, 'high': 177.079, 'highSource': '15 minute delayed price', 'highTime': 1695412799970, 'iexAskPrice': 0, 'iexAskSize': 0, 'iexBidPrice': 0, 'iexBidSize': 0, 'iexClose': 174.75, 'iexCloseTime': 1695412799286, 'iexLastUpdated': 1695412799286, 'iexMarketPercent': 0.019815273878362356, 'iexOpen': 174.59, 'iexOpenTime': 1695389400866, 'iexRealtimePrice': 174.75, 'iexRealtimeSize': 400, 'iexVolume': 1124029, 'lastTradeTime': 1695412799899, 'latestPrice': 174.79, 'latestSource': 'Close', 'latestTime': 'September 22, 2023', 'latestUpdate': 1695412800412, 'latestVolume': 56725383, 'low': 174.05, 'lowSource': '15 minute delayed price', 'lowTime': 1695390080947, 'marketCap': 2732707411280, 'oddLotDelayedPrice': 174.85, 'oddLotDelayedPriceTime': 1695412773248, 'open': 174.61, 'openTime': 1695389401180, 'openSource': 'official', 'peRatio': 29.38, 'previousClose': 173.93, 'previousVolume': 63149116, 'primaryExchange': 'NASDAQ', 'symbol': 'AAPL', 'volume': 56725383, 'week52High': 197.7, 'week52Low': 123.48, 'ytdChange': 0.3577660822453864, 'isUSMarketOpen': False}]

# %% [markdown]
# ## Parsing Our API Call
#
# The API call that we executed in the last code block contains all of the information required to build our equal-weight S&P 500 strategy.
#
# With that said, the data isn't in a proper format yet. We need to parse it first.

# %%
data[0]
# Out:
# {'avgTotalVolume': 66866726,
#  'calculationPrice': 'close',
#  'change': 0.86,
#  'changePercent': 0.00494,
#  'close': 174.79,
#  'closeSource': 'official',
#  'closeTime': 1695412800412,
#  'companyName': 'Apple Inc',
#  'currency': 'USD',
#  'delayedPrice': 174.85,
#  'delayedPriceTime': 1695412773227,
#  'extendedChange': 0.15,
#  'extendedChangePercent': 0.00086,
#  'extendedPrice': 174.94,
#  'extendedPriceTime': 1695427193007,
#  'high': 177.079,
#  'highSource': '15 minute delayed price',
#  'highTime': 1695412799970,
#  'iexAskPrice': 0,
#  'iexAskSize': 0,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
#  'iexClose': 174.75,
#  'iexCloseTime': 1695412799286,
#  'iexLastUpdated': 1695412799286,
#  'iexMarketPercent': 0.019815273878362356,
#  'iexOpen': 174.59,
#  'iexOpenTime': 1695389400866,
#  'iexRealtimePrice': 174.75,
#  'iexRealtimeSize': 400,
#  'iexVolume': 1124029,
#  'lastTradeTime': 1695412799899,
#  'latestPrice': 174.79,
#  'latestSource': 'Close',
#  'latestTime': 'September 22, 2023',
#  'latestUpdate': 1695412800412,
#  'latestVolume': 56725383,
#  'low': 174.05,
#  'lowSource': '15 minute delayed price',
#  'lowTime': 1695390080947,
#  'marketCap': 2732707411280,
#  'oddLotDelayedPrice': 174.85,
#  'oddLotDelayedPriceTime': 1695412773248,
#  'open': 174.61,
#  'openTime': 1695389401180,
#  'openSource': 'official',
#  'peRatio': 29.38,
#  'previousClose': 173.93,
#  'previousVolume': 63149116,
#  'primaryExchange': 'NASDAQ',
#  'symbol': 'AAPL',
#  'volume': 56725383,
#  'week52High': 197.7,
#  'week52Low': 123.48,
#  'ytdChange': 0.3577660822453864,
#  'isUSMarketOpen': False}

# %% [markdown]
# ## Adding Our Stocks Data to a Pandas DataFrame

# %%
my_columns = ['Ticker', 'Price','Market Capitalization', 'Number Of Shares to Buy']
final_dataframe = pd.DataFrame(columns = my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Price, Market Capitalization, Number Of Shares to Buy]
# Index: []

# %%
final_dataframe = final_dataframe.append(
                                        pd.Series(['AAPL', 
                                                   data[0]['latestPrice'], 
                                                   data[0]['marketCap'], 
                                                   'N/A'], 
                                                  index = my_columns), 
                                        ignore_index = True)
final_dataframe
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1145031801.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
#   Ticker   Price Market Capitalization Number Of Shares to Buy
# 0   AAPL  174.79         2732707411280                     N/A

# %% [markdown]
# ## Looping Through The Tickers in Our List of Stocks
#
# Using the same logic that we outlined above, we can pull data for all S&P 500 stocks and store their data in the DataFrame using a `for` loop.

# %%
final_dataframe = pd.DataFrame(columns = my_columns)
for symbol in stocks['Ticker']:
    api_url = f'https://hsdalgotrading.iex.cloud/v1/data/core/quote/{symbol}?token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(api_url).json()
    final_dataframe = final_dataframe.append(
                                        pd.Series([symbol, 
                                                   data[0]['latestPrice'], 
                                                   data[0]['marketCap'], 
                                                   'N/A'], 
                                                  index = my_columns), 
                                        ignore_index = True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17836\1382111019.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(

# %%
final_dataframe
# Out:
#     Ticker   Price Market Capitalization Number Of Shares to Buy
# 0        A  111.41           32597148085                     N/A
# 1      AAL   12.90            8428375424                     N/A
# 2      AAP   57.60            3425487034                     N/A
# 3     AAPL  174.79         2732707411280                     N/A
# 4     ABBV  152.74          269593229903                     N/A
# ..     ...     ...                   ...                     ...
# 500    YUM  125.00           35026410125                     N/A
# 501    ZBH  116.85           24417459058                     N/A
# 502   ZBRA  227.15           11661509383                     N/A
# 503   ZION   34.10            5051749035                     N/A
# 504    ZTS  176.68           81328790775                     N/A
#
# [505 rows x 4 columns]

# %% [markdown]
# ## Using Batch API Calls to Improve Performance
#
# Batch API calls are one of the easiest ways to improve the performance of your code.
#
# This is because HTTP requests are typically one of the slowest components of a script.
#
# Also, API providers will often give you discounted rates for using batch API calls since they are easier for the API provider to respond to.
#
# IEX Cloud limits their batch API calls to 100 tickers per request. Still, this reduces the number of API calls we'll make in this section from 500 to 5 - huge improvement! In this section, we'll split our list of stocks into groups of 100 and then make a batch API call for each group.

# %%
# Function sourced from 
# https://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks
# But not used
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

        
        
        
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
#     print(symbol_strings[i])

final_dataframe = pd.DataFrame(columns = my_columns)

for symbol_string in symbol_strings:
#     print(symbol_strings)
    batch_api_call_url = f'https://sandbox.iexapis.com/stable/stock/market/batch/?types=quote&symbols={symbol_string}&token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        final_dataframe = final_dataframe.append(
                                        pd.Series([symbol, 
                                                   data[symbol]['quote']['latestPrice'], 
                                                   data[symbol]['quote']['marketCap'], 
                                                   'N/A'], 
                                                  index = my_columns), 
                                        ignore_index = True)
        
    
final_dataframe

# %% [markdown]
# ## Calculating the Number of Shares to Buy

# %%
portfolio_size = input("Enter the value of your portfolio:")

try:
    val = float(portfolio_size)
except ValueError:
    print("That's not a number! \n Try again:")
    portfolio_size = input("Enter the value of your portfolio:")
# Out:
# Enter the value of your portfolio:10000

# %%
position_size = float(portfolio_size) / len(final_dataframe.index)
for i in range(0, len(final_dataframe['Ticker'])-1):
    final_dataframe.loc[i, 'Number Of Shares to Buy'] = math.floor(position_size / final_dataframe['Price'][i])
final_dataframe
# Out:
#     Ticker   Price Market Capitalization Number Of Shares to Buy
# 0        A  111.41           32597148085                       0
# 1      AAL   12.90            8428375424                       1
# 2      AAP   57.60            3425487034                       0
# 3     AAPL  174.79         2732707411280                       0
# 4     ABBV  152.74          269593229903                       0
# ..     ...     ...                   ...                     ...
# 500    YUM  125.00           35026410125                       0
# 501    ZBH  116.85           24417459058                       0
# 502   ZBRA  227.15           11661509383                       0
# 503   ZION   34.10            5051749035                       0
# 504    ZTS  176.68           81328790775                     N/A
#
# [505 rows x 4 columns]

# %%
final_dataframe = final_dataframe[final_dataframe["Number Of Shares to Buy"]!='N/A']
final_dataframe["Number Of Shares to Buy"].astype('int64')
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 499    0
# 500    0
# 501    0
# 502    0
# 503    0
# Name: Number Of Shares to Buy, Length: 504, dtype: int64

# %%
final_dataframe[final_dataframe["Number Of Shares to Buy"]>0]
# Out:
#     Ticker   Price Market Capitalization Number Of Shares to Buy
# 1      AAL  12.900            8428375424                       1
# 16     AES  15.960           10687279399                       1
# 19     AIV   7.070            1045147792                       2
# 30    AMCR   9.050           13108869524                       2
# 84     CCL  14.050           15725680837                       1
# 111   COTY  11.870           10182410870                       1
# 118    CTL  11.000           12072940000                       1
# 137   DISH   6.270            3327527855                       3
# 174      F  12.430           48866972928                       1
# 192    FRC   3.510             630560307                       5
# 208    GPS   9.940            3658914000                       1
# 214   HBAN  10.310           14927667895                       1
# 215    HBI   4.190            1466024963                       4
# 225    HPE  17.020           21834357517                       1
# 230    HST  15.800           11243356978                       1
# 253    IVZ  14.490            6500511683                       1
# 262    KEY  10.610            9930099762                       1
# 265    KIM  17.690           10965731579                       1
# 268    KMI  16.600           36987545092                       1
# 326    MYL  15.855            8586211830                       1
# 327    NBL   8.450            4095292500                       2
# 328   NCLH  15.660            6662133560                       1
# 347    NWL   8.970            3715374000                       2
# 349   NWSA  19.680           11376038229                       1
# 360   PBCT  19.410            8371850392                       1
# 362   PEAK  18.830           10301032243                       1
# 394     RF  17.060           16008719416                       1
# 429      T  15.120          107805600000                       1
# 452     UA   6.310            2694612588                       3
# 453    UAA   6.850            3038581362                       2
# 466    VFC  17.470            6793531193                       1
# 491     WU  13.050            4887679205                       1
# 498    XRX  16.090            2528061251                       1

# %% [markdown]
# ## For Our Excel Output
#
# ### Initializing our XlsxWriter Object

# %%
writer = pd.ExcelWriter('recommended_trades.xlsx', engine='xlsxwriter')
final_dataframe.to_excel(writer, sheet_name='Recommended Trades', index = False)

# %% [markdown]
# ### Creating the Formats We'll Need For Our `.xlsx` File
#
# Formats include colors, fonts, and also symbols like `%` and `$`. We'll need four main formats for our Excel document:
# * String format for tickers
# * \\$XX.XX format for stock prices
# * \\$XX,XXX format for market capitalization
# * Integer format for the number of shares to purchase

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
        {
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

dollar_format = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

integer_format = writer.book.add_format(
        {
            'num_format':'0',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

# %% [markdown]
# ### Applying the Formats to the Columns of Our `.xlsx` File
#
# We can use the `set_column` method applied to the `writer.sheets['Recommended Trades']` object to apply formats to specific columns of our spreadsheets.
#
# Here's an example:
#
# ```python
# writer.sheets['Recommended Trades'].set_column('B:B', #This tells the method to apply the format to column B
#                      18, #This tells the method to apply a column width of 18 pixels
#                      string_format #This applies the format 'string_format' to the column
#                     )
# ```

# %%
column_formats = { 
                    'A': ['Ticker', string_format],
                    'B': ['Price', dollar_format],
                    'C': ['Market Capitalization', dollar_format],
                    'D': ['Number of Shares to Buy', integer_format]
                    }

for column in column_formats.keys():
    writer.sheets['Recommended Trades'].set_column(f'{column}:{column}', 20, column_formats[column][1])
    writer.sheets['Recommended Trades'].write(f'{column}1', column_formats[column][0], string_format)

# %% [markdown]
# ## Saving Our Excel Output
#
# Saving our Excel file is very easy:

# %%
writer.save()
